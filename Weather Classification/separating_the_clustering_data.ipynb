# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('clustering.csv')
df.head()
# Out:
#    Clearsky DHI  GHI  cluster  Temperature  Clearsky DNI  Relative Humidity  \
# 0             0    0        0          5.0             0              63.52
# 1             0    0        0          4.7             0              65.31
# 2             0    0        0          6.2             0              75.81
# 3             0    0        0          5.6             0              79.06
# 4             0    0        0          5.0             0              82.37
#
#    Wind Speed  DNI  Cloud Type  Clearsky GHI  DHI  Solar Zenith Angle
# 0         1.4    0           0             0    0              174.62
# 1         1.4    0           0             0    0              161.76
# 2         1.3    0           0             0    0              148.34
# 3         1.3    0           0             0    0              134.93
# 4         1.4    0           0             0    0              121.67

# %%
DATA=df.loc[df['cluster'] == 0]

# %%
DATA.head()
# Out:
#    Clearsky DHI  GHI  cluster  Temperature  Clearsky DNI  Relative Humidity  \
# 0             0    0        0          5.0             0              63.52
# 1             0    0        0          4.7             0              65.31
# 2             0    0        0          6.2             0              75.81
# 3             0    0        0          5.6             0              79.06
# 4             0    0        0          5.0             0              82.37
#
#    Wind Speed  DNI  Cloud Type  Clearsky GHI  DHI  Solar Zenith Angle
# 0         1.4    0           0             0    0              174.62
# 1         1.4    0           0             0    0              161.76
# 2         1.3    0           0             0    0              148.34
# 3         1.3    0           0             0    0              134.93
# 4         1.4    0           0             0    0              121.67

# %%
DATA.shape
# Out:
# (5888, 12)

# %%
DATA.to_csv(r'E:\CatBoost_1\Johannesburg\K_mean_clustering\cloudy_cluster.csv', index = False)

# %%
data=df.loc[df['cluster'] == 1]

# %%
data.head()
# Out:
#     Clearsky DHI  GHI  cluster  Temperature  Clearsky DNI  Relative Humidity  \
# 10           108  403        1         14.5           889              40.65
# 11           114  702        1         15.7           920              36.14
# 12           115  715        1         16.4           923              33.37
# 13           111  657        1         16.7           901              31.61
# 14           100  533        1         16.6           854              30.95
#
#     Wind Speed  DNI  Cloud Type  Clearsky GHI  DHI  Solar Zenith Angle
# 10         3.4  241           7           618  265               54.95
# 11         3.7  920           0           702  114               50.20
# 12         3.9  923           0           715  115               49.41
# 13         4.0  901           1           657  111               52.76
# 14         4.0  854           0           533  100               59.55

# %%
data.to_csv(r'E:\CatBoost_1\Johannesburg\K_mean_clustering\sunny_cluster.csv', index = False)

# %%
data.shape
# Out:
# (2872, 12)
